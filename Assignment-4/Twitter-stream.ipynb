# %% [markdown]
# https://www.rittmanmead.com/blog/2017/01/getting-started-with-spark-streaming-with-python-and-kafka/

# %%
# !pip install tweepy

# %%
import json

import tweepy
from tweepy.streaming import StreamListener


class TweetListener(StreamListener):
    
    def __init__(self, csocket):
        self.client_socket = csocket
    
    def on_data(self, data):
        try:  
            # Load data
            msg = json.loads(data)
            # Read extended Tweet if available
            if "extended_tweet" in msg:
                # Add "__end" at the end of each Tweet 
                self.client_socket\
                    .send(str(msg['extended_tweet']['full_text']+" __end")\
                    .encode('utf-8'))         
                print(msg['extended_tweet']['full_text'])
            # Else read Tweet text
            else:
                # Add "__end" at the end of each Tweet
                self.client_socket\
                    .send(str(msg['text']+"__end")\
                    .encode('utf-8'))
                print(msg['text'])
            return True
        except BaseException as e:
            print("error on_data: %s" % str(e))
        return True
    
    def on_error(self, status):
        print(status)
        return True

# %%
from tweepy import Stream
from tweepy import OAuthHandler

from configuration import API_KEY, API_KEY_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET


def sendData(c_socket, keyword):
    print("Start sending data from Twitter to socket")
    # Authentication based on the developer credentials from twitter
    auth = OAuthHandler(API_KEY, API_KEY_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    # Send data from the Stream API
    twitter_stream = Stream(auth, TweetListener(c_socket))
    # Filter by keyword and language
    twitter_stream.filter(track = keyword, languages=["en"])

# %%
import socket


if __name__ == "__main__":
    # Create listening socket on server (local)
    s = socket.socket()
    # Host address and port
    host = "127.0.0.1"
    port = 5555
    s.bind((host, port))
    print("Socket is established")
    # Server listens for connections
    s.listen(4)
    print("Socket is listening")
    # Return the socket and the address of the client
    c_socket, addr = s.accept()
    print("Received request from: " + str(addr))
    # Send data to client via socket for selected keyword
    sendData(c_socket, keyword = ['covid'])
# Out:
# Socket is established
# Socket is listening
# Received request from: ('127.0.0.1', 44134)
# Start sending data from Twitter to socket
# RT @ANI: Uttarakhand: 20 patients escaped from a COVID care centre at Narendra Nagar in Tehri Garhwal
#
# Suman Arya, CMO says,"38 people were…
# RT @ndtv: Have Covid symptoms but still testing negative? This is what you should do
#
# NDTV's Sonal Mehrotra Kapoor explains
#
# #COVID19 https…
# RT @Msuppasitstudio: #MewMewChargingDay LIVE event will be postponed as recent COVID-19 situation. BUT..!! We have added more special gifts…
# RT @PChidambaram_IN: While Gujarat officially reported 78 Covid-caused deaths on Friday (17th April), the HINDU reported that 689 bodies we…
# RT @WhiteHouse: Today @POTUS spoke with German Chancellor Angela Merkel, affirming our cooperation to combat COVID-19, fight climate change…
# RT @Wahwouph: The actual numbers of covid deaths being suppressed. India in chaos! Civil war is imminent!
# RT @spectator: ‘No one at Public Health England or SAGE has ever presented any solid evidence that pubs and restaurants have been responsib…
# Small correction it should definitely have the picture but not of @narendramodi but of Xi J@inping.
# #chinaliedpeopledied
# The ex-Dutchess County corrections sergeant faces a felony charge of second-degree murder in connection to the death of 34-year-old Terrie DeGelormo. https://t.co/3kzHEAuHXi
# RT @Supriya23bh: Son abandoned his father -on road- in #Delhi after he was tested #COVID positive, but @DelhiPolice constable Mr Raju Ram t…
# RT @thakkar_sameet: When was the last time @AUThackeray addressed press ?
#
# Hai kha Maharashtra ka Shezaada?
#
# From the day Parambir wrote l…
# RT @aradwanski: Nothing against @David_Moscrop, but the @washingtonpost comment section’s relationship with Canadian politics remains deepl…
# RT @aaditeaa: RETWEET AND AMPLIFY
#
# THIS A GOOGLE DOCS FOR COVID RESOURCES WHICH IS UPDATED EVERY
# 5 MINS.
# Has info abt :
# Oxygen (Refill,…
# RT @bbclaurak: Perhaps the only surprise about cancelling this trip is that it took so long for the decision to be made
# RT @prarthanajalan: Yet another gem lost. Young CA Kapil Bohra from Raipur aged 32 years died due to covid 19.
# RT @indiatvnews: UP: Medical team on way to give medicines to COVID patient attacked
# https://t.co/SQCs69BrGW
# RT @AJEnglish: India’s rising COVID cases raise fears of new lockdowns, denting fuel demand in the key energy importer https://t.co/GHnl2jv…
# RT @Iamlistening666: @bbclaurak Boris Johnson 'doesn't regret' ignoring advice which could have avoided 'worst case' Covid-19. Documents re…
# RT @xpresskerala: #TNIENewsBulletin
# Sanu Mohan has confessed that he killed his daughter, say police, and Kerala plans to enforce strict r…
# RT @AriFleischer: “When Covid cases were rising, the news coverage emphasized the increase. When cases were falling, the coverage instead f…
# RT @DoubleDownNews: .@GeorgeMonbiot on Long Covid, Chronic Fatigue Syndrome &amp; Misogyny https://t.co/kd9VQTToeF
# RT @Rahul93321814: #ssc_jawab_do
# #postponesscchsl
# Why ?
# When exam have to do ...they don't have the management to do it .
# And when it's n…
# ANZAC Day hypocrisy over COVID-19 restrictions 'disgusts'https://t.co/TScqyx6ozp
#
# MR. PAUL 'MUPPET' MURRAY of the 'SKY NEWS MUPPET SHOW', THIS is JUST YOUR OWN SELF SERVING, OPINIONATED RHETORICAL DIATRIBE, not backed up BY ANY SUBSTANTIAL PROVABLE DATA! EXPECT MORE DID WE? SAD!
# RT @nkda_mar: Tune in to Radio New Town to know about Covid protocols #TrustNKDA https://t.co/pdL3y67T5P
# RT @ToniaBuxton: Please could a scientist explain why need to vaccinate children for Covid.
# RT @VidyaKrishnan: Not to mention that the Union Health Minister and Chair of @WHO 's executive board @drharshvardhan is plainly stating he…
# RT @visrane: I extend my gratitude to Smt. @shailajateacher Madam, Hon Health Minister of Kerala for helping us with movement of 20,000 lit…
# @mla_sudhakar
# One of our employee who had registered for vaccination was told that there was no stock of COVID vaccine and was told to come back after 3 days by JSS Hospital, Chamrajnagar. How long will the state government lie about vaccine shortages? #VaccineShortage #Covid_19
# Gathering on behest of @pfiofficial and violation of covid rules is killing of humanity.
#
# #ArrestSarwarChishty
# RT @srinivasiyc: I am trying to arrange this plasma / plasma donor asap. #SOSIYC
# RT @AlokRaj12345691: SSC must postpone the SSC CHSL 2020 exam immediately otherwise students will get covid &amp; infect their families too! @d…
# Sign me up 10 days of sleeping and scratching my baws again sounds magic
# RT @timesofindia: Delhi Covid lockdown | It has been decided to impose a lockdown in Delhi, from 10 pm tonight to 6 am next Monday (26th Ap…
# RT @samominayeon: having a foreign line breakdown bc momo, sana, mina, and tzuyu all went to korea away from their home to chase their drea…
# RT @johnpavlovitz: God thinks this is stupid.
# RT @ANI: Recovery trials showed that steroids will benefit but it's also imp to know when they're given. If given early before your saturat…
# RT @JuuustineS: https://t.co/7TzKjVoRSr
#
# If you’re in the accounting/auditing industry or know someone who is, please could you fill in thi…
# RT @Asad_Umar: Global covid cases exceeding  750,000 per day and deaths more than 13,000. We are seeing some of the worst numbers since cov…
# RT @RichardGrenell: Dr Fauci has never missed a paycheck through Covid 19 - which is why he is completely tone-deaf to the economic health…
# RT @PiushSharma28: Nice initiative.
# Pl participate in the Nobel cause. https://t.co/1aymMjPBzx
# RT @SalmanNizami_: Religion teaches us love only. Muslim NGO in Mumbai has started free Oxygen cylinder service for COVID patients. Don’t l…
# RT @phekuuu: Two min silence for all those who said 2021 will be better than 2020 🤐💔
# it’s actually tough and we don’t even realize what’s h…
# RT @DailyExposeNews: Full Fact recently released a fact checking article in which they concluded the mRNA vaccines Pfizer &amp; Moderna Covid v…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8ec7ac128248> in <module>
#      17     print("Received request from: " + str(addr))
#      18     # Send data to client via socket for selected keyword
# ---> 19     sendData(c_socket, keyword = ['covid'])
#
# <ipython-input-3-7d309515a992> in sendData(c_socket, keyword)
#      13     twitter_stream = Stream(auth, TweetListener(c_socket))
#      14     # Filter by keyword and language
# ---> 15     twitter_stream.filter(track = keyword, languages=["en"])
#
# /opt/conda/lib/python3.8/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /opt/conda/lib/python3.8/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /opt/conda/lib/python3.8/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /opt/conda/lib/python3.8/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /opt/conda/lib/python3.8/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /opt/conda/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# /opt/conda/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# /opt/conda/lib/python3.8/http/client.py in readinto(self, b)
#     490
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#     494         if self.length is not None:
#
# /opt/conda/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     585         try:
#     586             while True:
# --> 587                 chunk_left = self._get_chunk_left()
#     588                 if chunk_left is None:
#     589                     return total_bytes
#
# /opt/conda/lib/python3.8/http/client.py in _get_chunk_left(self)
#     553                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     554             try:
# --> 555                 chunk_left = self._read_next_chunk_size()
#     556             except ValueError:
#     557                 raise IncompleteRead(b'')
#
# /opt/conda/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     513     def _read_next_chunk_size(self):
#     514         # Read the next chunk size from the file
# --> 515         line = self.fp.readline(_MAXLINE + 1)
#     516         if len(line) > _MAXLINE:
#     517             raise LineTooLong("chunk size")
#
# /opt/conda/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /opt/conda/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
